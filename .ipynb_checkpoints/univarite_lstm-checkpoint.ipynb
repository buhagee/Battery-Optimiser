# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import seaborn as sns
import custom_module as cm

from keras.models import Model, load_model
from keras.layers.convolutional import Conv1D
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l1_l2

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import json

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
data = pd.read_csv('combined_data.csv', parse_dates=True)

# %%
data["SETTLEMENTDATE"] = pd.to_datetime(data["SETTLEMENTDATE"])
data.index = data["SETTLEMENTDATE"]
data.drop(columns="SETTLEMENTDATE", inplace=True)
data = data["2017-01-01":"2019-6-30"]
X_test = data["2019-01-01":"2019-06-30"]
X_test = X_test["RRP5MIN"]
data = cm.replace_outliers(data, 'RRP5MIN', 3)

# %%
scaler_label = MinMaxScaler()
scaler_feature = MinMaxScaler()

# %%
data['RRP5MIN'] = scaler_label.fit_transform(data['RRP5MIN'].values.reshape(-1, 1))
data['RESIDUAL_DEMAND'] = scaler_feature.fit_transform(data['RESIDUAL_DEMAND'].values.reshape(-1, 1))
train = data.copy()

# %%
lags = 250
for i in range(1,lags+1):
    train["lp_{}".format(i)] = train["RRP5MIN"].shift(i)
    train["ld_{}".format(i)] = train["RESIDUAL_DEMAND"].shift(i)

# %%
train.dropna(inplace=True)

# %%
prelim_features = train.drop(['RRP5MIN', "RESIDUAL_DEMAND"], axis=1)
prelim_labels = pd.DataFrame(train['RRP5MIN'])

# %%
# format labels to 24 hour output range
for i in range(0, 288):
    prelim_labels['t_{}'.format(i)] = prelim_labels['RRP5MIN'].shift(-i)
prelim_labels.drop('RRP5MIN', axis=1, inplace=True)
#print(prelim_labels.head())

#print("DISCRETIZATION OF DATA")
# apply one-day discretization to the data
labels = prelim_labels[prelim_labels.index.minute == 0]
labels = labels[labels.index.hour == 0]
features = prelim_features[prelim_features.index.minute == 0]
features = features[features.index.hour == 0]

features_train = features[:'2018']
features_test = features['2019':'2019-06-30']
labels_train = labels[:'2018']

#print(features_train.iloc[0])
#print(features_test.iloc[0])

samples_train = len(features_train)
samples_test = len(features_test)
#print(samples_train)#
#print(samples_test)

timesteps = 250

# convert pandas data frames to numpy ndarrays
features_train = features_train.to_numpy().reshape(samples_train, timesteps, 2)
features_test = features_test.to_numpy().reshape(samples_test, timesteps, 2)
labels_train = labels_train.to_numpy()

# check for correct data shape
print(features_train.shape, labels_train.shape)
# Out:
# (729, 250, 2) (729, 288)

# %%
features.loc["2019"]
# Out:
#                     lp_1      ld_1      lp_2      ld_2      lp_3      ld_3  \
# SETTLEMENTDATE
# 2019-01-01      0.465637  0.366138  0.466881  0.367400  0.478593  0.365164
# 2019-01-02      0.442219  0.302370  0.460920  0.307806  0.480115  0.305990
# 2019-01-03      0.473304  0.323664  0.475793  0.330574  0.475793  0.337891
# 2019-01-04      0.569547  0.604678  0.629947  0.610834  0.800351  0.618445
# 2019-01-05      0.527961  0.350182  0.542474  0.360614  0.540906  0.357409
# ...                  ...       ...       ...       ...       ...       ...
# 2019-06-26      0.573145  0.517916  0.573145  0.524637  0.573145  0.523446
# 2019-06-27      0.474627  0.330961  0.512792  0.335172  0.520055  0.342918
# 2019-06-28      0.285432  0.146181  0.334739  0.151835  0.332642  0.155678
# 2019-06-29      0.388134  0.247772  0.397511  0.245829  0.397649  0.249695
# 2019-06-30      0.397229  0.301029  0.415961  0.312339  0.411503  0.301133
#
#                     lp_4      ld_4      lp_5      ld_5  ...    lp_246  \
# SETTLEMENTDATE                                          ...
# 2019-01-01      0.477011  0.364503  0.476594  0.355988  ...  0.455864
# 2019-01-02      0.491829  0.303356  0.509599  0.304813  ...  0.411645
# 2019-01-03      0.476683  0.324395  0.486207  0.324324  ...  0.366462
# 2019-01-04      1.000000  0.618660  1.000000  0.622196  ...  0.390631
# 2019-01-05      0.540922  0.352136  0.588302  0.352077  ...  0.302407
# ...                  ...       ...       ...       ...  ...       ...
# 2019-06-26      0.573145  0.526496  0.573146  0.526199  ...  0.418972
# 2019-06-27      0.522606  0.347810  0.610950  0.348064  ...  0.377242
# 2019-06-28      0.351083  0.166847  0.370147  0.179064  ...  0.347995
# 2019-06-29      0.388712  0.245544  0.426407  0.240661  ...  0.334465
# 2019-06-30      0.423382  0.296798  0.433390  0.292347  ...  0.207888
#
#                   ld_246    lp_247    ld_247    lp_248    ld_248    lp_249  \
# SETTLEMENTDATE
# 2019-01-01      0.368620  0.463949  0.370267  0.465104  0.374811  0.460110
# 2019-01-02      0.331232  0.412996  0.347169  0.422763  0.358606  0.429848
# 2019-01-03      0.250664  0.395366  0.236252  0.387989  0.233654  0.389976
# 2019-01-04      0.277190  0.390559  0.276408  0.413534  0.286066  0.398959
# 2019-01-05      0.282336  0.300114  0.308495  0.384065  0.307380  0.377030
# ...                  ...       ...       ...       ...       ...       ...
# 2019-06-26      0.286448  0.418323  0.326951  0.422503  0.329216  0.422707
# 2019-06-27      0.225388  0.385072  0.247040  0.380700  0.246752  0.387927
# 2019-06-28      0.112323  0.347951  0.116974  0.347973  0.116545  0.335803
# 2019-06-29      0.115356  0.334209  0.118010  0.334268  0.117180  0.332252
# 2019-06-30      0.119171  0.210215  0.123181  0.210215  0.118968  0.210216
#
#                   ld_249    lp_250    ld_250
# SETTLEMENTDATE
# 2019-01-01      0.377121  0.465091  0.378677
# 2019-01-02      0.353531  0.433893  0.359292
# 2019-01-03      0.240836  0.388090  0.239511
# 2019-01-04      0.281347  0.397944  0.280777
# 2019-01-05      0.309899  0.411098  0.315318
# ...                  ...       ...       ...
# 2019-06-26      0.323785  0.424108  0.319701
# 2019-06-27      0.244055  0.413994  0.250232
# 2019-06-28      0.110111  0.349016  0.116649
# 2019-06-29      0.123003  0.335112  0.118211
# 2019-06-30      0.129620  0.207880  0.123740
#
# [181 rows x 500 columns]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(features_train, labels_train, test_size=0.2, random_state=7)

# %%
# Initialising
rnn = Sequential()
# Adding Conv1D Layer
rnn.add(Conv1D(64, kernel_size=250, strides=250, padding='valid', input_shape=(X_train.shape[1],2)))
# Add LSTM layer 1st
rnn.add(LSTM(50, recurrent_activation='relu', return_sequences=True))
rnn.add(Dropout(0.1))
# Add LSTM layer 2nd
#rnn.add(LSTM(50, recurrent_activation='relu'))
#rnn.add(Dropout(0.1))
rnn.add(Dense(units=288))
rnn.compile(optimizer='adam', loss='mse')

# %%
def train_predict_evaluate(model, X_train, X_valid, y_train, y_valid, X_test, y_test, test_index, scaler, 
                           batch_size, epochs, filename='model.hdf5', verbose=0):
    
    """Fit model to training data. Use best performant on validation data to predict for the test set. 
    Evaluate on the test set and return results as dataframes"""
    
    # train model, save best keep best performer on validation set
    checkpoint = ModelCheckpoint('./models/' + filename, save_best_only=True)
    hist = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), callbacks=[checkpoint], 
                     verbose=verbose, batch_size=batch_size, epochs=epochs)
    
    # load best model
    best = load_model('./models/' + filename)

    # predict for test set
    pred = best.predict(X_test)
    
    
    # transform back to original data scale
    pred = scaler.inverse_transform(pred.flatten().reshape(-1, 1))
    results = pd.DataFrame({'prediction':pred.flatten(), 'true values':y_test}, index=test_index)
    
    return results, hist

# %%
# train the model and calculate the performance on the test set
results, hist = train_predict_evaluate(rnn, X_train, X_valid, y_train, y_valid, features_test,
                                       X_test.to_numpy().flatten(), X_test.index, scaler_label, 32, 160,
                                       'simple_neural_network.hdf5', verbose=1)

print(rnn.summary())
# Out:
# Epoch 1/160
# 19/19 [==============================] - 0s 19ms/step - loss: 0.2441 - val_loss: 0.1578
# Epoch 2/160
# 19/19 [==============================] - 0s 6ms/step - loss: 0.1083 - val_loss: 0.0447
# Epoch 3/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0437 - val_loss: 0.0251
# Epoch 4/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0215
# Epoch 5/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0285 - val_loss: 0.0207
# Epoch 6/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0286 - val_loss: 0.0212
# Epoch 7/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0290 - val_loss: 0.0199
# Epoch 8/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0260 - val_loss: 0.0200
# Epoch 9/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0260 - val_loss: 0.0197
# Epoch 10/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0250 - val_loss: 0.0189
# Epoch 11/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0249 - val_loss: 0.0193
# Epoch 12/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0233 - val_loss: 0.0194
# Epoch 13/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0237 - val_loss: 0.0193
# Epoch 14/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0234 - val_loss: 0.0222
# Epoch 15/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0251 - val_loss: 0.0194
# Epoch 16/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0237 - val_loss: 0.0185
# Epoch 17/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0219 - val_loss: 0.0180
# Epoch 18/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0220 - val_loss: 0.0191
# Epoch 19/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0217 - val_loss: 0.0180
# Epoch 20/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0213 - val_loss: 0.0195
# Epoch 21/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0218 - val_loss: 0.0183
# Epoch 22/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0210 - val_loss: 0.0175
# Epoch 23/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0203 - val_loss: 0.0174
# Epoch 24/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0211 - val_loss: 0.0199
# Epoch 25/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0210 - val_loss: 0.0177
# Epoch 26/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0207 - val_loss: 0.0192
# Epoch 27/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0206 - val_loss: 0.0174
# Epoch 28/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0199 - val_loss: 0.0172
# Epoch 29/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0198 - val_loss: 0.0170
# Epoch 30/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0204 - val_loss: 0.0172
# Epoch 31/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0201 - val_loss: 0.0171
# Epoch 32/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0193 - val_loss: 0.0172
# Epoch 33/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0207 - val_loss: 0.0176
# Epoch 34/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0195 - val_loss: 0.0170
# Epoch 35/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0195 - val_loss: 0.0181
# Epoch 36/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0195 - val_loss: 0.0172
# Epoch 37/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0191 - val_loss: 0.0186
# Epoch 38/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0205 - val_loss: 0.0173
# Epoch 39/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0195 - val_loss: 0.0170
# Epoch 40/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0188 - val_loss: 0.0169
# Epoch 41/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0190 - val_loss: 0.0176
# Epoch 42/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0196 - val_loss: 0.0178
# Epoch 43/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0195 - val_loss: 0.0173
# Epoch 44/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0190 - val_loss: 0.0168
# Epoch 45/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0188 - val_loss: 0.0169
# Epoch 46/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0185 - val_loss: 0.0168
# Epoch 47/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0186 - val_loss: 0.0167
# Epoch 48/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0183 - val_loss: 0.0172
# Epoch 49/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0185 - val_loss: 0.0170
# Epoch 50/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0181 - val_loss: 0.0215
# Epoch 51/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0203 - val_loss: 0.0188
# Epoch 52/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0186 - val_loss: 0.0167
# Epoch 53/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0188 - val_loss: 0.0168
# Epoch 54/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0192 - val_loss: 0.0198
# Epoch 55/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0191 - val_loss: 0.0170
# Epoch 56/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0184 - val_loss: 0.0181
# Epoch 57/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0183 - val_loss: 0.0170
# Epoch 58/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0185 - val_loss: 0.0168
# Epoch 59/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0187 - val_loss: 0.0198
# Epoch 60/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0183 - val_loss: 0.0168
# Epoch 61/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0181 - val_loss: 0.0166
# Epoch 62/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0190 - val_loss: 0.0175
# Epoch 63/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0191 - val_loss: 0.0169
# Epoch 64/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0186 - val_loss: 0.0168
# Epoch 65/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0183 - val_loss: 0.0165
# Epoch 66/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0182 - val_loss: 0.0166
# Epoch 67/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0176
# Epoch 68/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0187 - val_loss: 0.0204
# Epoch 69/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0187 - val_loss: 0.0172
# Epoch 70/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0190 - val_loss: 0.0170
# Epoch 71/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0182 - val_loss: 0.0166
# Epoch 72/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0181 - val_loss: 0.0166
# Epoch 73/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0181 - val_loss: 0.0168
# Epoch 74/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0181 - val_loss: 0.0166
# Epoch 75/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0185 - val_loss: 0.0165
# Epoch 76/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0182 - val_loss: 0.0166
# Epoch 77/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0178 - val_loss: 0.0173
# Epoch 78/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0185 - val_loss: 0.0166
# Epoch 79/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0184 - val_loss: 0.0175
# Epoch 80/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0182 - val_loss: 0.0187
# Epoch 81/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0182 - val_loss: 0.0166
# Epoch 82/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0183 - val_loss: 0.0166
# Epoch 83/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0192 - val_loss: 0.0181
# Epoch 84/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0189 - val_loss: 0.0167
# Epoch 85/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0166
# Epoch 86/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0183 - val_loss: 0.0168
# Epoch 87/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0182 - val_loss: 0.0169
# Epoch 88/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0179 - val_loss: 0.0165
# Epoch 89/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0177 - val_loss: 0.0164
# Epoch 90/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0170
# Epoch 91/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0178 - val_loss: 0.0167
# Epoch 92/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0181 - val_loss: 0.0172
# Epoch 93/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0181 - val_loss: 0.0167
# Epoch 94/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0183 - val_loss: 0.0165
# Epoch 95/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0176
# Epoch 96/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0181 - val_loss: 0.0172
# Epoch 97/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0165
# Epoch 98/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0166
# Epoch 99/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0169
# Epoch 100/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0179 - val_loss: 0.0165
# Epoch 101/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0176 - val_loss: 0.0167
# Epoch 102/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0167
# Epoch 103/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0164
# Epoch 104/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0175 - val_loss: 0.0164
# Epoch 105/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0166
# Epoch 106/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0175 - val_loss: 0.0164
# Epoch 107/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0178 - val_loss: 0.0167
# Epoch 108/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0164
# Epoch 109/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0167
# Epoch 110/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0179 - val_loss: 0.0165
# Epoch 111/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0165
# Epoch 112/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0165
# Epoch 113/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0173
# Epoch 114/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0168
# Epoch 115/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0181 - val_loss: 0.0165
# Epoch 116/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0168
# Epoch 117/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0166
# Epoch 118/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0164
# Epoch 119/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0176 - val_loss: 0.0183
# Epoch 120/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0179 - val_loss: 0.0165
# Epoch 121/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0171
# Epoch 122/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0169
# Epoch 123/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0183 - val_loss: 0.0176
# Epoch 124/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0186 - val_loss: 0.0169
# Epoch 125/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0172
# Epoch 126/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0179 - val_loss: 0.0169
# Epoch 127/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0192
# Epoch 128/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0186 - val_loss: 0.0179
# Epoch 129/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.0165
# Epoch 130/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0176 - val_loss: 0.0164
# Epoch 131/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0174 - val_loss: 0.0164
# Epoch 132/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0173
# Epoch 133/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0176 - val_loss: 0.0165
# Epoch 134/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0176 - val_loss: 0.0164
# Epoch 135/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0174 - val_loss: 0.0177
# Epoch 136/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0176 - val_loss: 0.0168
# Epoch 137/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0172 - val_loss: 0.0165
# Epoch 138/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0172 - val_loss: 0.0164
# Epoch 139/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0173
# Epoch 140/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0176 - val_loss: 0.0164
# Epoch 141/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0178 - val_loss: 0.0165
# Epoch 142/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0164
# Epoch 143/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0172 - val_loss: 0.0168
# Epoch 144/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0164
# Epoch 145/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0172 - val_loss: 0.0164
# Epoch 146/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0173 - val_loss: 0.0165
# Epoch 147/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0174 - val_loss: 0.0166
# Epoch 148/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0172 - val_loss: 0.0166
# Epoch 149/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0165
# Epoch 150/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0172 - val_loss: 0.0165
# Epoch 151/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0174 - val_loss: 0.0164
# Epoch 152/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0173 - val_loss: 0.0164
# Epoch 153/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0172 - val_loss: 0.0167
# Epoch 154/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0173 - val_loss: 0.0174
# Epoch 155/160
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0171 - val_loss: 0.0164
# Epoch 156/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0171 - val_loss: 0.0166
# Epoch 157/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0172 - val_loss: 0.0164
# Epoch 158/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0172 - val_loss: 0.0167
# Epoch 159/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0171 - val_loss: 0.0165
# Epoch 160/160
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0171 - val_loss: 0.0169
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 1, 64)             32064
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 50)             23000
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 50)             0
# _________________________________________________________________
# dense (Dense)                (None, 1, 288)            14688
# =================================================================
# Total params: 69,752
# Trainable params: 69,752
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
results["2019-01-01":"2019-01-13"].plot()
# Out:
# <AxesSubplot:xlabel='SETTLEMENTDATE'>

# %%
results.to_csv("final_model_report_results.csv")
# Out:
#                      prediction  true values
# SETTLEMENTDATE
# 2019-01-01 00:00:00    6.727466     6.583450
# 2019-01-01 00:05:00    7.466034     6.375000
# 2019-01-01 00:10:00    7.499975     6.438173
# 2019-01-01 00:15:00    7.151686     6.375000
# 2019-01-01 00:20:00    6.811754     6.375000
# ...                         ...          ...
# 2019-06-30 23:35:00   10.087289     6.134757
# 2019-06-30 23:40:00    9.158204     5.998145
# 2019-06-30 23:45:00    8.517952     5.961220
# 2019-06-30 23:50:00    7.852262     5.066510
# 2019-06-30 23:55:00    7.181921     5.002401
#
# [52128 rows x 2 columns]
