# %%
##################################################################
############# FORECASTING DAY AHEAD ENERGY PRICE ################
################################################################

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
#import timeseries as ts
from sklearn.preprocessing import MinMaxScaler, StandardScaler
#from sklearn.externals import joblib
import seaborn as sns

# %%
data = pd.read_csv("combined_energy.csv", parse_dates=True)

# %%
from datetime import datetime as dt
data["SETTLEMENTDATE"] = pd.to_datetime(data["SETTLEMENTDATE"])

# Seperating data for each region
dataSA = data[data["REGIONID"] == "SA1"]

# Setting Index to Date
dataSA = dataSA[["SETTLEMENTDATE","RRP5min"]]
dataSA.index = dataSA["SETTLEMENTDATE"]
dataSA.drop(columns="SETTLEMENTDATE", inplace=True)

# %%
dataSA.loc["2008-02-25"]
# Out:
# Empty DataFrame
# Columns: [RRP5min]
# Index: []

# %%
# Convert data into hourly time frame
dataSA = dataSA.resample('H').sum()

# %%
# plot the price full price data set
ax = dataSA.loc['2010'].plot(figsize=(12, 5), legend=False)

# %%
# keep raw data of the test set for model evaluation
test_raw = dataSA['2010']

def replace_outliers(data, column, tolerance):

    """Replace outliers out of 75% + tolerance * IQR or 25% - tolerance * IQR by these thresholds"""
    
    tol = tolerance
    data_prep = data.copy(deep=True)
    
    # calculate quantiles and inter-quantile range of the data
    q75 = data_prep[column].quantile(.75)
    q25 = data_prep[column].quantile(.25)
    IQR = q75 - q25

    # values larger (smaller) than q75 (q25) plus 'tol' times IQR get replaced by that value
    data_prep[column] = data_prep[column].apply(lambda x: q75 + tol * IQR if (x > q75 + tol * IQR) else x)
    data_prep[column] = data_prep[column].apply(lambda x: q25 - tol * IQR if (x < q75 - tol * IQR) else x)
    
    return data_prep

# %%
# replace outliers by outlier threshold
dataSA = replace_outliers(dataSA, 'RRP5min', 3)

# %%
# Scaling the RRP between 0 and 1 as required by the NN
scaler = MinMaxScaler()
dataSA["RRP5min"] = scaler.fit_transform(dataSA["RRP5min"].values.reshape(-1,1))

# %%
f, ax = plt.subplots(figsize=(12, 6))
dataSA.hist(bins=50, ax=ax)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe81b180700>],
#       dtype=object)

# %%
dataSA
# Out:
#                       RRP5min
# SETTLEMENTDATE
# 2008-01-07 00:00:00  0.556747
# 2008-01-07 01:00:00  0.551866
# 2008-01-07 02:00:00  0.511425
# 2008-01-07 03:00:00  0.490760
# 2008-01-07 04:00:00  0.488235
# ...                       ...
# 2010-12-06 19:00:00  0.623703
# 2010-12-06 20:00:00  0.796981
# 2010-12-06 21:00:00  0.953477
# 2010-12-06 22:00:00  0.693964
# 2010-12-06 23:00:00  0.605345
#
# [25560 rows x 1 columns]

# %%
feature_data = dataSA.loc['2009-06-12':'2009-06-18', 'RRP5min']
feature_data.columns = ['input data']
label_data = dataSA.loc['2009-06-18', 'RRP5min']
label_data.columns = ['data to predict']
f, ax = plt.subplots(figsize=(10, 6))
feature_data.plot(ax=ax)
label_data.plot(ax=ax, color='red')
ax.set_ylabel('Relative price', fontsize=14)
ax.set_xlabel('Date', fontsize=14)
ax.set_title('Timeseries Model Data Structure', fontsize=14);

# %%
# include time lags of timeseries data for 1 week = 7 * 24h = 168h
lags = 168
for i in range(1,lags+1):
    dataSA["l_{}".format(i)] = dataSA["RRP5min"].shift(i)

# %%
# Drop NANS
dataSA.dropna(inplace=True)
dataSA.head(5)
# Out:
#                       RRP5min       l_1       l_2       l_3       l_4  \
# SETTLEMENTDATE
# 2008-01-14 00:00:00  0.428571  0.428571  0.428571  0.428571  0.428571
# 2008-01-14 01:00:00  0.428571  0.428571  0.428571  0.428571  0.428571
# 2008-01-14 02:00:00  0.428571  0.428571  0.428571  0.428571  0.428571
# 2008-01-14 03:00:00  0.428571  0.428571  0.428571  0.428571  0.428571
# 2008-01-14 04:00:00  0.428571  0.428571  0.428571  0.428571  0.428571
#
#                           l_5       l_6       l_7       l_8       l_9  ...  \
# SETTLEMENTDATE                                                         ...
# 2008-01-14 00:00:00  0.428571  0.428571  0.428571  0.428571  0.428571  ...
# 2008-01-14 01:00:00  0.428571  0.428571  0.428571  0.428571  0.428571  ...
# 2008-01-14 02:00:00  0.428571  0.428571  0.428571  0.428571  0.428571  ...
# 2008-01-14 03:00:00  0.428571  0.428571  0.428571  0.428571  0.428571  ...
# 2008-01-14 04:00:00  0.428571  0.428571  0.428571  0.428571  0.428571  ...
#
#                         l_159     l_160     l_161     l_162     l_163  \
# SETTLEMENTDATE
# 2008-01-14 00:00:00  0.597893  0.610081  0.577235  0.541780  0.495068
# 2008-01-14 01:00:00  0.588719  0.597893  0.610081  0.577235  0.541780
# 2008-01-14 02:00:00  0.561118  0.588719  0.597893  0.610081  0.577235
# 2008-01-14 03:00:00  0.558987  0.561118  0.588719  0.597893  0.610081
# 2008-01-14 04:00:00  0.565323  0.558987  0.561118  0.588719  0.597893
#
#                         l_164     l_165     l_166     l_167     l_168
# SETTLEMENTDATE
# 2008-01-14 00:00:00  0.488235  0.490760  0.511425  0.551866  0.556747
# 2008-01-14 01:00:00  0.495068  0.488235  0.490760  0.511425  0.551866
# 2008-01-14 02:00:00  0.541780  0.495068  0.488235  0.490760  0.511425
# 2008-01-14 03:00:00  0.577235  0.541780  0.495068  0.488235  0.490760
# 2008-01-14 04:00:00  0.610081  0.577235  0.541780  0.495068  0.488235
#
# [5 rows x 169 columns]

# %%
# create feature and label dataframes
prelim_features = dataSA.drop('RRP5min', axis=1)
prelim_labels = pd.DataFrame(dataSA['RRP5min'])

# %%
# format labels to 24 hour output range
for i in range(0, 24):
    prelim_labels['t_{}'.format(i)] = prelim_labels['RRP5min'].shift(-i)
prelim_labels.drop('RRP5min', axis=1, inplace=True)

# apply one-day discretization to the data
labels = prelim_labels[prelim_labels.index.hour == 0]
features = prelim_features[prelim_features.index.hour == 0]

features_train = features[:'2009']
features_test = features['2010':]
labels_train = labels[:'2009']

samples_train = len(features_train)
samples_test = len(features_test)
timesteps = 168

# convert pandas data frames to numpy ndarrays
features_train = features_train.to_numpy().reshape(samples_train, timesteps, 1)
features_test = features_test.to_numpy().reshape(samples_test, timesteps, 1)
labels_train = labels_train.to_numpy()

# check for correct data shape
features_train.shape, labels_train.shape
# Out:
# ((718, 168, 1), (718, 24))

# %%
from keras.models import Model, load_model
from keras.layers import Input, Add
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers.convolutional import Conv1D
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l1_l2
from tensorflow.keras.layers import Dropout as dp

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import json

# %%
# split into training and validation data
X_train, X_valid, y_train, y_valid = train_test_split(features_train, labels_train, test_size=0.2, random_state=7)

# %%
def train_predict_evaluate(model, X_train, X_valid, y_train, y_valid, X_test, y_test, test_index, scaler, 
                           batch_size, epochs, filename='model.hdf5', verbose=0):
    
    """Fit model to training data. Use best performant on validation data to predict for the test set. 
    Evaluate on the test set and return results as dataframes"""
    
    # train model, save best keep best performer on validation set
    checkpoint = ModelCheckpoint('./models/' + filename, save_best_only=True)
    hist = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), callbacks=[checkpoint], 
                     verbose=verbose, batch_size=batch_size, epochs=epochs)
    
    # load best model
    best = load_model('./models/' + filename)

    # predict for test set
    pred = best.predict(X_test)
    
    
    # transform back to original data scale
    pred = scaler.inverse_transform(pred.flatten().reshape(-1, 1))
    results = pd.DataFrame({'prediction':pred.flatten(), 'true values':y_test}, index=test_index)
    
    return results, hist

# %%
# design the neural network architecture with the keras functional API
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
x = Conv1D(64, kernel_size=24, strides=24, padding='valid')(input_layer)
x = LSTM(50, recurrent_activation='relu')(x)
#x = LSTM(50, recurrent_activation='relu')(x)
#x = dp(0.2)(x) # NO ONE NEURON TO AFFECT MUCH. COMMENT THIS
output_layer = Dense(24)(x)
model = Model(inputs=[input_layer], outputs=[output_layer])
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 168, 1)]          0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 7, 64)             1600
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 50)                23000
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                1224
# =================================================================
# Total params: 25,824
# Trainable params: 25,824
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model and calculate the performance on the test set
results, hist = train_predict_evaluate(model, X_train, X_valid, y_train, y_valid, features_test,
                                       test_raw.to_numpy().flatten(), test_raw.index, scaler, 100, 200, 
                                       'simple_neural_network.hdf5', verbose=1)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s 110ms/step - loss: 0.2889 - val_loss: 0.2785
# Epoch 2/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2606 - val_loss: 0.2348
# Epoch 3/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2087 - val_loss: 0.1771
# Epoch 4/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1573 - val_loss: 0.1334
# Epoch 5/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1185 - val_loss: 0.1000
# Epoch 6/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0897 - val_loss: 0.0766
# Epoch 7/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0679 - val_loss: 0.0551
# Epoch 8/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0485 - val_loss: 0.0379
# Epoch 9/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0332 - val_loss: 0.0253
# Epoch 10/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.0227 - val_loss: 0.0170
# Epoch 11/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0159 - val_loss: 0.0118
# Epoch 12/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0118 - val_loss: 0.0088
# Epoch 13/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0097 - val_loss: 0.0075
# Epoch 14/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0089 - val_loss: 0.0073
# Epoch 15/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0088 - val_loss: 0.0072
# Epoch 16/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0088 - val_loss: 0.0072
# Epoch 17/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0087 - val_loss: 0.0071
# Epoch 18/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0086 - val_loss: 0.0070
# Epoch 19/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0086 - val_loss: 0.0070
# Epoch 20/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0084 - val_loss: 0.0069
# Epoch 21/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0084 - val_loss: 0.0068
# Epoch 22/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0083 - val_loss: 0.0068
# Epoch 23/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0083 - val_loss: 0.0067
# Epoch 24/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0082 - val_loss: 0.0066
# Epoch 25/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0081 - val_loss: 0.0066
# Epoch 26/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0080 - val_loss: 0.0064
# Epoch 27/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0079 - val_loss: 0.0064
# Epoch 28/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0079 - val_loss: 0.0064
# Epoch 29/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0078 - val_loss: 0.0063
# Epoch 30/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0078 - val_loss: 0.0062
# Epoch 31/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0078 - val_loss: 0.0062
# Epoch 32/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0077 - val_loss: 0.0062
# Epoch 33/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0076 - val_loss: 0.0060
# Epoch 34/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 35/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0075 - val_loss: 0.0059
# Epoch 36/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0074 - val_loss: 0.0060
# Epoch 37/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0062
# Epoch 38/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0074 - val_loss: 0.0058
# Epoch 39/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0073 - val_loss: 0.0057
# Epoch 40/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0072 - val_loss: 0.0057
# Epoch 41/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0073 - val_loss: 0.0056
# Epoch 42/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 43/200
# 6/6 [==============================] - 1s 130ms/step - loss: 0.0074 - val_loss: 0.0055
# Epoch 44/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0071 - val_loss: 0.0057
# Epoch 45/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0071 - val_loss: 0.0057
# Epoch 46/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0070 - val_loss: 0.0057
# Epoch 47/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0071 - val_loss: 0.0053
# Epoch 48/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.0070 - val_loss: 0.0053
# Epoch 49/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0069 - val_loss: 0.0053
# Epoch 50/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0069 - val_loss: 0.0052
# Epoch 51/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0066 - val_loss: 0.0054
# Epoch 52/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0068 - val_loss: 0.0053
# Epoch 53/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0065 - val_loss: 0.0051
# Epoch 54/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0065 - val_loss: 0.0053
# Epoch 55/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0065 - val_loss: 0.0049
# Epoch 56/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0066 - val_loss: 0.0049
# Epoch 57/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0064 - val_loss: 0.0050
# Epoch 58/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0063 - val_loss: 0.0047
# Epoch 59/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0062 - val_loss: 0.0051
# Epoch 60/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0061 - val_loss: 0.0047
# Epoch 61/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.0060 - val_loss: 0.0046
# Epoch 62/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0059 - val_loss: 0.0045
# Epoch 63/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0059 - val_loss: 0.0045
# Epoch 64/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 0.0045
# Epoch 65/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 66/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0058 - val_loss: 0.0045
# Epoch 67/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 68/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0058 - val_loss: 0.0045
# Epoch 69/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0058 - val_loss: 0.0044
# Epoch 70/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0056 - val_loss: 0.0043
# Epoch 71/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0055 - val_loss: 0.0042
# Epoch 72/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0055 - val_loss: 0.0042
# Epoch 73/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0056 - val_loss: 0.0047
# Epoch 74/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0056 - val_loss: 0.0042
# Epoch 75/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.0054 - val_loss: 0.0041
# Epoch 76/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 77/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 78/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0054 - val_loss: 0.0045
# Epoch 79/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 80/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 81/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0055 - val_loss: 0.0043
# Epoch 82/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 83/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 84/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 85/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 86/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 87/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 88/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0054 - val_loss: 0.0040
# Epoch 89/200
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0056 - val_loss: 0.0040
# Epoch 90/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0054 - val_loss: 0.0042
# Epoch 91/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 92/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 93/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0050 - val_loss: 0.0039
# Epoch 94/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 95/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 96/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 97/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 98/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 99/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 100/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0051 - val_loss: 0.0039
# Epoch 101/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 102/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 103/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 104/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0050 - val_loss: 0.0041
# Epoch 105/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 106/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 107/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0049 - val_loss: 0.0038
# Epoch 108/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 109/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 110/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 111/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 112/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 113/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0049 - val_loss: 0.0041
# Epoch 114/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 115/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0050 - val_loss: 0.0038
# Epoch 116/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 117/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 118/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 119/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 120/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0049 - val_loss: 0.0038
# Epoch 121/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 122/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0049 - val_loss: 0.0041
# Epoch 123/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 124/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 125/200
# 6/6 [==============================] - 0s 67ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 126/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 127/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 128/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 129/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 130/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 131/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0049 - val_loss: 0.0041
# Epoch 132/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0050 - val_loss: 0.0040
# Epoch 133/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0049 - val_loss: 0.0041
# Epoch 134/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0050 - val_loss: 0.0043
# Epoch 135/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 136/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0053 - val_loss: 0.0040
# Epoch 137/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 138/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 139/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.0049 - val_loss: 0.0038
# Epoch 140/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0049 - val_loss: 0.0038
# Epoch 141/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0049 - val_loss: 0.0038
# Epoch 142/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 143/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 144/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 145/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 146/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 147/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 148/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 149/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 150/200
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 151/200
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 152/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 153/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 154/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 155/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 156/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 157/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 158/200
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 159/200
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 160/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 161/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 162/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 163/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 164/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 165/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 166/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 167/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 168/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 169/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 170/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0037
# Epoch 171/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0042
# Epoch 172/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 173/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 174/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 175/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 176/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 177/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 178/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 179/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 180/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 181/200
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 182/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 183/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 184/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 185/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 186/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 187/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 188/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 189/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 190/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 191/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 192/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 193/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 194/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 195/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 196/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 197/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 198/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 199/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 200/200
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0040

# %%
f, ax = plt.subplots(figsize=(12, 6))
results.plot(ax=ax)
ax.set_ylabel('Day-Ahead price in €/MWh', fontsize=14)
ax.set_xlabel('Date', fontsize=14)
ax.set_title('Long Term Predictive Performance', fontsize=14);

# %%
f, ax = plt.subplots(figsize=(12, 6))
results.loc['2010-01-01':'2010-01-7'].plot(ax=ax);
ax.set_ylabel('Day-Ahead price in $/MWh', fontsize=14)
ax.set_xlabel('Date', fontsize=14)
ax.set_title('Short Term predictive Performance', fontsize=14);

# %%
results.head(100)
# Out:
#                      prediction  true values
# SETTLEMENTDATE
# 2010-01-01 00:00:00   24.287838    20.187360
# 2010-01-01 01:00:00   23.054758    19.032720
# 2010-01-01 02:00:00   17.142508    15.678975
# 2010-01-01 03:00:00   14.919151    12.610706
# 2010-01-01 04:00:00   15.074835    12.786080
# ...                         ...          ...
# 2010-01-04 23:00:00   14.914762    19.836879
# 2010-01-05 00:00:00   16.788910    26.819425
# 2010-01-05 01:00:00   14.892385    25.734549
# 2010-01-05 02:00:00    9.840273    21.764889
# 2010-01-05 03:00:00    8.429996    19.535283
#
# [100 rows x 2 columns]

# %%
print('MAE: ', mean_absolute_error(y_pred=results['prediction'], y_true=results['true values']))
# Out:
# MAE:  23.547804467051368
